# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("HARtrain.csv")

# %%
df
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-X.1  tBodyAcc-mean()-X.2  \
# 0              0.288585            -0.020294            -0.132905
# 1              0.278419            -0.016411            -0.123520
# 2              0.279653            -0.019467            -0.113462
# 3              0.279174            -0.026201            -0.123283
# 4              0.276629            -0.016570            -0.115362
# ...                 ...                  ...                  ...
# 7347           0.299665            -0.057193            -0.181233
# 7348           0.273853            -0.007749            -0.147468
# 7349           0.273387            -0.017011            -0.045022
# 7350           0.289654            -0.018843            -0.158281
# 7351           0.351503            -0.012423            -0.203867
#
#       tBodyAcc-mean()-X.3  tBodyAcc-mean()-X.4  tBodyAcc-mean()-X.5  \
# 0               -0.995279            -0.983111            -0.913526
# ...

# %%
df.shape
# Out:
# (7352, 563)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#                        tBodyAcc-mean()-X  tBodyAcc-mean()-X.1  \
# tBodyAcc-mean()-X               1.000000             0.148061
# tBodyAcc-mean()-X.1             0.148061             1.000000
# tBodyAcc-mean()-X.2            -0.256952            -0.078769
# tBodyAcc-mean()-X.3             0.000619            -0.045160
# tBodyAcc-mean()-X.4            -0.021903            -0.044920
# ...                                  ...                  ...
# tBodyAcc-mean()-X.557           0.028844             0.075679
# tBodyAcc-mean()-X.558          -0.035257            -0.005309
# tBodyAcc-mean()-X.559           0.034371             0.001053
# tBodyAcc-mean()-X.560           0.028242            -0.013903
# tBodyAcc-mean()-X.561           0.024181            -0.003144
#
#                        tBodyAcc-mean()-X.2  tBodyAcc-mean()-X.3  \
# tBodyAcc-mean()-X                -0.256952             0.000619
# tBodyAcc-mean()-X.1              -0.078769            -0.045160
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to tBodyAcc-mean()-X.562
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
df.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-X.1  tBodyAcc-mean()-X.2  \
# count        7352.000000          7352.000000          7352.000000
# mean            0.274488            -0.017695            -0.109141
# std             0.070261             0.040811             0.056635
# min            -1.000000            -1.000000            -1.000000
# 25%             0.262975            -0.024863            -0.120993
# 50%             0.277193            -0.017219            -0.108676
# 75%             0.288461            -0.010783            -0.097794
# max             1.000000             1.000000             1.000000
#
#        tBodyAcc-mean()-X.3  tBodyAcc-mean()-X.4  tBodyAcc-mean()-X.5  \
# count          7352.000000          7352.000000          7352.000000
# mean             -0.605438            -0.510938            -0.604754
# std               0.448734             0.502645             0.418687
# min              -1.000000            -0.999873            -1.000000
# ...

# %%
df['tBodyAcc-mean()-X.562'].unique()
# Out:
# array(['STANDING', 'SITTING', 'LAYING', 'WALKING', 'WALKING_DOWNSTAIRS',
#        'WALKING_UPSTAIRS'], dtype=object)

# %%
df['tBodyAcc-mean()-X.562'].replace({'STANDING':1, 'SITTING':2, 'LAYING':3, 'WALKING':4, 'WALKING_DOWNSTAIRS':6,
       'WALKING_UPSTAIRS':7},inplace=True)

# %%
df
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-X.1  tBodyAcc-mean()-X.2  \
# 0              0.288585            -0.020294            -0.132905
# 1              0.278419            -0.016411            -0.123520
# 2              0.279653            -0.019467            -0.113462
# 3              0.279174            -0.026201            -0.123283
# 4              0.276629            -0.016570            -0.115362
# ...                 ...                  ...                  ...
# 7347           0.299665            -0.057193            -0.181233
# 7348           0.273853            -0.007749            -0.147468
# 7349           0.273387            -0.017011            -0.045022
# 7350           0.289654            -0.018843            -0.158281
# 7351           0.351503            -0.012423            -0.203867
#
#       tBodyAcc-mean()-X.3  tBodyAcc-mean()-X.4  tBodyAcc-mean()-X.5  \
# 0               -0.995279            -0.983111            -0.913526
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
Numerical_features=[feature for feature in df.columns if df[feature].dtype!='O']

# %%
len(Numerical_features)#so all features are numerical in the data except last columns i.e.,activities
# Out:
# 563

# %%
X=df.iloc[:,:562]

# %%
X
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-X.1  tBodyAcc-mean()-X.2  \
# 0              0.288585            -0.020294            -0.132905
# 1              0.278419            -0.016411            -0.123520
# 2              0.279653            -0.019467            -0.113462
# 3              0.279174            -0.026201            -0.123283
# 4              0.276629            -0.016570            -0.115362
# ...                 ...                  ...                  ...
# 7347           0.299665            -0.057193            -0.181233
# 7348           0.273853            -0.007749            -0.147468
# 7349           0.273387            -0.017011            -0.045022
# 7350           0.289654            -0.018843            -0.158281
# 7351           0.351503            -0.012423            -0.203867
#
#       tBodyAcc-mean()-X.3  tBodyAcc-mean()-X.4  tBodyAcc-mean()-X.5  \
# 0               -0.995279            -0.983111            -0.913526
# ...

# %%
y=pd.DataFrame(df.iloc[:,-1])

# %%
y
# Out:
#       tBodyAcc-mean()-X.562
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
# ...                     ...
# 7347                      7
# 7348                      7
# 7349                      7
# 7350                      7
# 7351                      7
#
# [7352 rows x 1 columns]

# %% [markdown]
# # Training the model

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (5881, 562) (5881, 1) (1471, 562) (1471, 1)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# C:\Users\wwwka\AppData\Local\Temp/ipykernel_7320/1593328843.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train,y_train)
# RandomForestClassifier()

# %%
rf.score(X_train,y_train)
# Out:
# 1.0

# %%
rf.score(X_test,y_test)
# Out:
# 0.981645139360979

# %%
y_pred=rf.predict(X_test)

# %%
y_pred
# Out:
# array([3, 1, 6, ..., 3, 2, 2], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.9897976534602959

# %%
lr.score(X_test,y_test)
# Out:
# 0.9782460910944936

# %%
from sklearn.linear_model import LinearRegression
lrg=LinearRegression()

# %%
lrg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lrg.score(X_train,y_train)
# Out:
# 0.9704947514802843

# %%
lrg.score(X_test,y_test)
# Out:
# 0.961400698007632

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.98      0.95      0.96       286
#            2       0.95      0.98      0.96       267
#            3       1.00      1.00      1.00       285
#            4       0.98      0.99      0.99       242
#            6       0.98      1.00      0.99       193
#            7       1.00      0.97      0.99       198
#
#     accuracy                           0.98      1471
#    macro avg       0.98      0.98      0.98      1471
# weighted avg       0.98      0.98      0.98      1471

# %%
pred=lrg.predict(X_test)

# %%
print(confusion_matrix(y_pred,y_test))
# Out:
# [[272  14   0   0   0   0]
#  [  6 261   0   0   0   0]
#  [  0   0 285   0   0   0]
#  [  0   0   0 240   2   0]
#  [  0   0   0   0 193   0]
#  [  0   0   0   4   1 193]]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(X_train,y_train)
# Out:
# 1.0

# %%
dt.score(X_test,y_test)
# Out:
# 0.9340584636301835

# %%
pred1=dt.predict(X_test)

# %%
print(classification_report(pred1,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.92      0.92      0.92       278
#            2       0.92      0.92      0.92       275
#            3       1.00      1.00      1.00       285
#            4       0.95      0.91      0.93       254
#            6       0.91      0.93      0.92       193
#            7       0.87      0.90      0.88       186
#
#     accuracy                           0.93      1471
#    macro avg       0.93      0.93      0.93      1471
# weighted avg       0.93      0.93      0.93      1471
